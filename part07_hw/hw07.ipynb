# %%
import pandas as pd
import numpy as np
mpg = pd.read_csv('mpg.csv')

# %% [markdown]
# ### 데이터 전처리 및 가공 2 - 결측치

# %%
mpg.loc[[64, 123, 130, 152, 211], 'hwy'] = np.nan

# %%
pd.isna(mpg['drv']).sum()
# Out:
# np.int64(0)

# %%
pd.isna(mpg['hwy']).sum()
# Out:
# np.int64(5)

# %% [markdown]
# hwy에만 5개의 결측치가 있는 것을 확인했다.
# 이제 hwy의 결측치를 제거하고 hwy 평균을 비교해보자.

# %%
mpg['drv'].unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %% [markdown]
# drv의 종류를 먼저 확인했다.

# %%
mpg.dropna(subset=['hwy']).groupby('drv')['hwy'].mean()
# Out:
# drv
# 4    19.242424
# f    28.200000
# r    21.000000
# Name: hwy, dtype: float64

# %% [markdown]
# 하나의 pandas 구문을 통해 hwy의 평균을 비교해봤다. 그 결과 f 인 전륜구동의 평균이 가장 높은 것을 확인할 수 있다.

# %% [markdown]
# ### 데이터 전처리 및 가공 2- 이상치
